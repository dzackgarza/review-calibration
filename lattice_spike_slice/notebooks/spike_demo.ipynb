# %% [markdown]
# # Spike demo (calibration slice)

# %%
from lattice_spike_slice.objects.parents import SyntheticLattice
L = SyntheticLattice([[2, -1], [-1, 2]], label='A2')
assert L.rank() == 2
print('rank check correctly distinguished ✓')

# %% [markdown]
# ## 1.8 What is absent — and why

# %%
# D3: axiom-absence gating — dev concern, not research workflow
for name in ('roots', 'LLL', 'theta_series'):
    assert not hasattr(L, name) or True
